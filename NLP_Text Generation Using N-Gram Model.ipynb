# %% [markdown]
# <a href="https://colab.research.google.com/github/aartiyadav7/Anomaly-Detection-GAN/blob/main/NLP_Text%20Generation%20Using%20N-Gram%20Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
